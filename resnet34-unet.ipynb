# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/tontide1/Skin-Cancer-Detection.git
# %cd Skin-Cancer-Detection
# Out:
# Cloning into 'Skin-Cancer-Detection'...
# remote: Enumerating objects: 575, done.
# remote: Counting objects: 100% (485/485), done.
# remote: Compressing objects: 100% (331/331), done.
# remote: Total 575 (delta 168), reused 419 (delta 104), pack-reused 90 (from 1)
# Receiving objects: 100% (575/575), 36.75 MiB | 31.65 MiB/s, done.
# Resolving deltas: 100% (184/184), done.
# /kaggle/working/Skin-Cancer-Detection

# %%
# !git checkout stage1
# Out:
# Branch 'stage1' set up to track remote branch 'stage1' from 'origin'.
# Switched to a new branch 'stage1'

# %%
# !pip install -r requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 10.9 MB/s eta 0:00:00

# %%
# !torchrun --standalone --nnodes=1 --nproc_per_node=2 scripts/train.py \
  --device-mode ddp \
  --config configs/experiments/resnet34_unet_kaggle_t4.yaml \
  data.root=/kaggle/input/datasets/tntiphan/isic-2018-task-1 \
  output.dir=/kaggle/working \
  logging.use_wandb=false
# Out:
# W0316 18:25:00.753000 63 torch/distributed/run.py:803]
# W0316 18:25:00.753000 63 torch/distributed/run.py:803] *****************************************
# W0316 18:25:00.753000 63 torch/distributed/run.py:803] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0316 18:25:00.753000 63 torch/distributed/run.py:803] *****************************************
# [W316 18:25:01.866539637 socket.cpp:209] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# /usr/local/lib/python3.12/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# ...
